# %%
# !Python -V
# Out:
# Python 3.10.12

# %%
# !Python --version
# Out:
# Python 3.10.12

# %% [markdown]
# ## test comment (Markdown)

# %%
# !pip install numpy
# Out:
# ...
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/b7/db/4d37359e2c9cf8bf071c08b8a6f7374648a5ab2e76e2e22e3b808f81d507/numpy-1.25.2-cp310-cp310-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/15.6 MB 558.5 kB/s eta 0:00:28
#    ---------------------------------------- 0.2/15.6 MB 1.0 MB/s eta 0:00:15
#     --------------------------------------- 0.3/15.6 MB 1.2 MB/s eta 0:00:13
#    - -------------------------------------- 0.4/15.6 MB 1.6 MB/s eta 0:00:10
#    - -------------------------------------- 0.5/15.6 MB 1.8 MB/s eta 0:00:09
#    - -------------------------------------- 0.7/15.6 MB 1.9 MB/s eta 0:00:08
# ...

# %% [markdown]
# ## !pip install numpy เรียกใช้ไดฟ์ & pip install numpy เรียกใช้ตัวrunปัจจุบัน

# %%
import numpy

# %%
print (numpy.__version__)
# Out:
# 1.25.2

# %%
import numpy as np

# %%
nt = np.array({1,2,3,4})

# %%
print(nt)
# Out:
# {1, 2, 3, 4}

# %%
nt.ndim
# Out:
# 0
